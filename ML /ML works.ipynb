# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
from datetime import datetime

# %%
nyc_sights = pd.read_csv('nyc_sightings cleaned updated.csv')
nyc_sights.columns = map(str.lower, nyc_sights.columns)
nyc_sights.head(30)
# Out:
#    time of reported rat sighting                  location type  incident zip  \
# 0                     9:38:29 AM          Other (Explain Below)       11432.0
# 1                     7:09:56 AM              Catch Basin/Sewer       11204.0
# 2                     9:04:46 AM   3+ Family Mixed Use Building       11375.0
# 3                     6:27:59 PM   3+ Family Mixed Use Building       11233.0
# 4                    12:50:16 PM        3+ Family Apt. Building       10034.0
# 5                     1:07:42 PM        3+ Family Apt. Building       10452.0
# 6                    12:09:47 PM            Government Building       11377.0
# 7                     1:37:04 PM            1-2 Family Dwelling       11236.0
# 8                    11:06:30 PM        3+ Family Apt. Building       10459.0
# 9                    12:49:49 PM        3+ Family Apt. Building       10455.0
# 10                   11:27:03 AM        3+ Family Apt. Building       11220.0
# 11                   10:43:47 AM        3+ Family Apt. Building       11225.0
# 12                    9:37:45 PM        3+ Family Apt. Building       11210.0
# 13                   12:20:25 AM        3+ Family Apt. Building       10458.0
# 14                    1:59:53 PM  1-2 Family Mixed Use Building       11432.0
# 15                   11:05:45 AM              Catch Basin/Sewer           NaN
# 16                    9:20:32 AM        3+ Family Apt. Building       10457.0
# 17                    7:04:44 AM            Commercial Building       10306.0
# 18                   10:45:14 AM        3+ Family Apt. Building       11221.0
# 19                   12:51:36 PM  1-2 Family Mixed Use Building       10024.0
# 20                   12:51:35 PM            1-2 Family Dwelling       10456.0
# 21                   12:51:00 PM            1-2 Family Dwelling       11367.0
# 22                    2:06:14 PM  1-2 Family Mixed Use Building       11209.0
# 23                   10:14:34 AM          Other (Explain Below)       10036.0
# 24                   12:00:19 PM            Commercial Building       10024.0
# 25                    7:52:52 AM        3+ Family Apt. Building       10032.0
# 26                   10:05:31 AM            1-2 Family Dwelling       10014.0
# 27                    3:50:50 PM        3+ Family Apt. Building       11216.0
# 28                    3:38:48 PM        3+ Family Apt. Building       11206.0
# 29                    3:19:29 PM        3+ Family Apt. Building       10029.0
#
#               incident address           city resolution action updated date  \
# 0                          NaN        JAMAICA                     9:45:41 AM
# 1                          NaN       BROOKLYN                     7:17:22 AM
# 2   68-12 YELLOWSTON BOULEVARD   FOREST HILLS                     9:14:11 AM
# 3         1040 HERKIMER STREET       BROOKLYN                     6:37:44 PM
# 4           241 SHERMAN AVENUE       NEW YORK                     1:00:54 PM
# 5           1270 GERARD AVENUE          BRONX                     1:13:07 PM
# 6               50-03 BROADWAY       WOODSIDE                    12:25:16 PM
# 7           764 EAST 82 STREET       BROOKLYN                     1:51:46 PM
# 8       1083 LONGFELLOW AVENUE          BRONX                    11:13:20 PM
# 9             732 UNION AVENUE          BRONX                    12:59:52 PM
# 10               504 44 STREET       BROOKLYN                    11:34:26 AM
# 11         320 STERLING STREET       BROOKLYN                    10:53:08 AM
# 12        1415 NEW YORK AVENUE       BROOKLYN                     9:43:01 PM
# 13         325 EAST 194 STREET          BRONX                    12:26:42 AM
# 14      169-10 HILLSIDE AVENUE        JAMAICA                     2:13:12 PM
# 15                         NaN            NaN                    11:12:50 AM
# 16      1977 LAFONTAINE AVENUE          BRONX                     9:30:04 AM
# 17  1375 NORTH RAILROAD AVENUE  STATEN ISLAND                     7:15:19 AM
# 18          1118 PUTNAM AVENUE       BROOKLYN                    10:51:29 AM
# 19          201 WEST 85 STREET       NEW YORK                    12:56:13 PM
# 20          751 TRINITY AVENUE          BRONX                    12:58:18 PM
# 21            144-34 76 AVENUE       FLUSHING                    12:57:16 PM
# 22               8116 5 AVENUE       BROOKLYN                     2:17:16 PM
# 23              WEST 42 STREET       NEW YORK                    10:23:01 AM
# 24        520 AMSTERDAM AVENUE       NEW YORK                    12:12:17 PM
# 25         506 WEST 172 STREET       NEW YORK                     7:57:23 AM
# 26          304 WEST 11 STREET       NEW YORK                    10:13:34 AM
# 27          781 PROSPECT PLACE       BROOKLYN                     3:57:33 PM
# 28       721 WILLOUGHBY AVENUE       BROOKLYN                     3:51:11 PM
# 29         347 EAST 109 STREET       NEW YORK                     3:27:23 PM
#
#           borough  x coordinate (state plane)  y coordinate (state plane)  \
# 0          QUEENS                   1039647.0                    195586.0
# 1        BROOKLYN                    990421.0                    160893.0
# 2          QUEENS                   1026289.0                    203836.0
# 3        BROOKLYN                   1006739.0                    186285.0
# 4       MANHATTAN                   1006543.0                    254798.0
# 5           BRONX                   1006574.0                    244239.0
# 6          QUEENS                   1009299.0                    214196.0
# 7        BROOKLYN                   1008652.0                    171260.0
# 8           BRONX                   1015294.0                    240146.0
# 9           BRONX                   1010915.0                    237068.0
# 10       BROOKLYN                    982464.0                    175441.0
# 11       BROOKLYN                    998073.0                    180888.0
# 12       BROOKLYN                    999432.0                    171786.0
# 13          BRONX                   1014228.0                    254195.0
# 14         QUEENS                   1041690.0                    198301.0
# 15       BROOKLYN                         NaN                         NaN
# 16          BRONX                   1013538.0                    247820.0
# 17  STATEN ISLAND                    952064.0                    148705.0
# 18       BROOKLYN                   1006930.0                    190172.0
# 19      MANHATTAN                    990972.0                    226040.0
# 20          BRONX                   1009812.0                    237667.0
# 21         QUEENS                   1034437.0                    202700.0
# 22       BROOKLYN                    977438.0                    166930.0
# 23      MANHATTAN                    985398.0                    216087.0
# 24      MANHATTAN                    991049.0                    226043.0
# 25      MANHATTAN                   1002094.0                    246213.0
# 26      MANHATTAN                    982537.0                    207350.0
# 27       BROOKLYN                    997890.0                    184969.0
# 28       BROOKLYN                   1000950.0                    192476.0
# 29      MANHATTAN                   1000895.0                    227859.0
#
#      latitude  longitude                                  location
# 0   40.703342 -73.800203   (40.70334174980328, -73.80020318978804)
# 1   40.608288 -73.977775   (40.60828832742201, -73.97777515791093)
# 2   40.726060 -73.848329  (40.726059538480236, -73.84832900182792)
# 3   40.677957 -73.918921   (40.67795748580213, -73.91892129635086)
# 4   40.866008 -73.919401    (40.86600810878767, -73.9194006525354)
# 5   40.837027 -73.919324   (40.83702671984958, -73.91932373285213)
# 6   40.754560 -73.909588   (40.75455957560568, -73.90958797579815)
# 7   40.636712 -73.912079     (40.636712112318, -73.91207880680062)
# 8   40.825766 -73.887830    (40.8257662713477, -73.88782966595178)
# 9   40.817332 -73.903664   (40.817332341679716, -73.9036643897699)
# 10  40.648221 -74.006436   (40.64822149214479, -74.00643612459912)
# 11  40.663162 -73.950176  (40.663161704647315, -73.95017554238143)
# 12  40.638176 -73.945298  (40.638176471740216, -73.94529756947061)
# 13  40.864330 -73.891619  (40.864330304739255, -73.89161859982286)
# 14  40.710781 -73.792812   (40.71078073687075, -73.79281169918012)
# 15        NaN        NaN                                       NaN
# 16  40.846835 -73.894141   (40.84683516208759, -73.89414105177033)
# 17  40.574778 -74.115860   (40.57477843506139, -74.11585968133437)
# 18  40.688626 -73.918220  (40.688625922973856, -73.91821960891517)
# 19  40.787101 -73.975726    (40.7871011921247, -73.97572571479215)
# 20  40.818980 -73.907647   (40.81897968795557, -73.90764703592707)
# 21  40.722899 -73.818941   (40.72289902523578, -73.81894067367983)
# 22  40.624858 -74.024539   (40.62485817130947, -74.02453949284964)
# 23  40.759785 -73.995856   (40.75978529474806, -73.99585607694812)
# 24  40.787109 -73.975448   (40.78710936742024, -73.97544765167478)
# 25  40.842455 -73.935509  (40.842454962346665, -73.93550865859358)
# 26  40.735804 -74.006181    (40.73580433551887, -74.0061811719475)
# 27  40.674363 -73.950827   (40.67436342129068, -73.95082690110178)
# 28  40.694963 -73.939777   (40.69496317326789, -73.93977679659866)
# 29  40.792081 -73.939888   (40.792080739254175, -73.9398875743932)

# %%
nyc_sights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216938 entries, 0 to 216937
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   time of reported rat sighting   216938 non-null  object
#  1   location type                   216926 non-null  object
#  2   incident zip                    216508 non-null  float64
#  3   incident address                206003 non-null  object
#  4   city                            213507 non-null  object
#  5   resolution action updated date  208656 non-null  object
#  6   borough                         216934 non-null  object
#  7   x coordinate (state plane)      214753 non-null  float64
#  8   y coordinate (state plane)      214755 non-null  float64
#  9   latitude                        214753 non-null  float64
#  10  longitude                       214753 non-null  float64
#  11  location                        214753 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 19.9+ MB

# %%
#changing the values of borough in the nyc_sights to lower case so that the data can merge with nyc_pop
nyc_sights['borough'] = nyc_sights['borough'].str.lower()

# %%
nyc_sights.head(5)
# Out:
#   time of reported rat sighting                 location type  incident zip  \
# 0                    9:38:29 AM         Other (Explain Below)       11432.0
# 1                    7:09:56 AM             Catch Basin/Sewer       11204.0
# 2                    9:04:46 AM  3+ Family Mixed Use Building       11375.0
# 3                    6:27:59 PM  3+ Family Mixed Use Building       11233.0
# 4                   12:50:16 PM       3+ Family Apt. Building       10034.0
#
#              incident address          city resolution action updated date  \
# 0                         NaN       JAMAICA                     9:45:41 AM
# 1                         NaN      BROOKLYN                     7:17:22 AM
# 2  68-12 YELLOWSTON BOULEVARD  FOREST HILLS                     9:14:11 AM
# 3        1040 HERKIMER STREET      BROOKLYN                     6:37:44 PM
# 4          241 SHERMAN AVENUE      NEW YORK                     1:00:54 PM
#
#      borough  x coordinate (state plane)  y coordinate (state plane)  \
# 0     queens                   1039647.0                    195586.0
# 1   brooklyn                    990421.0                    160893.0
# 2     queens                   1026289.0                    203836.0
# 3   brooklyn                   1006739.0                    186285.0
# 4  manhattan                   1006543.0                    254798.0
#
#     latitude  longitude                                  location
# 0  40.703342 -73.800203   (40.70334174980328, -73.80020318978804)
# 1  40.608288 -73.977775   (40.60828832742201, -73.97777515791093)
# 2  40.726060 -73.848329  (40.726059538480236, -73.84832900182792)
# 3  40.677957 -73.918921   (40.67795748580213, -73.91892129635086)
# 4  40.866008 -73.919401    (40.86600810878767, -73.9194006525354)

# %%
nyc_pop = pd.read_csv('nyc_projected_pop as is.csv')
nyc_pop.columns = map(str.lower, nyc_pop.columns)
nyc_pop.head(10)
# Out:
#               age group           borough       2010  \
# 0                 Total     New York City  8,242,624
# 1                 Total             Bronx  1,385,108
# 2                 Total          Brooklyn  2,552,911
# 3                 Total         Manhattan  1,585,873
# 4                 Total            Queens  2,250,002
# 5                 Total     Staten Island    468,730
# 6  School-Age (5 to17)      New York City  1,260,400
# 7  School-Age (5 to17)              Bronx    265,052
# 8  School-Age (5 to17)           Brooklyn    424,704
# 9  School-Age (5 to17)          Manhattan    157,856
#
#   % of total borough population - 2010       2020  \
# 0                              100.00%  8,550,971
# 1                              100.00%  1,446,788
# 2                              100.00%  2,648,452
# 3                              100.00%  1,638,281
# 4                              100.00%  2,330,295
# 5                              100.00%    487,155
# 6                               15.29%  1,282,814
# 7                               19.14%    259,013
# 8                               16.64%    441,049
# 9                                9.95%    162,931
#
#   % of total borough population - 2020       2030  \
# 0                              100.00%  8,821,027
# 1                              100.00%  1,518,998
# 2                              100.00%  2,754,009
# 3                              100.00%  1,676,720
# 4                              100.00%  2,373,551
# 5                              100.00%    497,749
# 6                               15.00%  1,347,036
# 7                               17.90%    277,830
# 8                               16.65%    461,688
# 9                                9.95%    177,440
#
#   % of total borough population - 2030       2040  \
# 0                              100.00%  9,025,145
# 1                              100.00%  1,579,245
# 2                              100.00%  2,840,525
# 3                              100.00%  1,691,617
# 4                              100.00%  2,412,649
# 5                              100.00%    501,109
# 6                               15.27%  1,342,097
# 7                               18.29%    281,688
# 8                               16.76%    454,949
# 9                               10.58%    170,114
#
#   % of total borough population - 2040 change in number - 2010-2020  \
# 0                              100.00%                      308,347
# 1                              100.00%                       61,680
# 2                              100.00%                       95,541
# 3                              100.00%                       52,408
# 4                              100.00%                       80,293
# 5                              100.00%                       18,425
# 6                               14.87%                       22,415
# 7                               17.84%                       -6,039
# 8                               16.02%                       16,345
# 9                               10.06%                        5,075
#
#   change in percent - 2010-2020 change in number - 2020-2030   \
# 0                         3.74%                       270,056
# 1                         4.45%                        72,210
# 2                         3.74%                       105,557
# 3                         3.30%                        38,439
# 4                         3.57%                        43,256
# 5                         3.93%                        10,594
# 6                         1.78%                        64,222
# 7                        -2.28%                        18,817
# 8                         3.85%                        20,639
# 9                         3.21%                        14,509
#
#   change in percent - 2020-2030 change in number - 2030-2040   \
# 0                         3.16%                       204,118
# 1                         4.99%                        60,247
# 2                         3.99%                        86,516
# 3                            2%                        14,897
# 4                         1.86%                        39,098
# 5                         2.17%                         3,360
# 6                         5.01%                        -4,939
# 7                         7.26%                         3,858
# 8                         4.68%                        -6,739
# 9                         8.90%                        -7,326
#
#   change in percent - 2030-2040 change in number - 2010-2040   \
# 0                         2.31%                       782,521
# 1                         3.97%                       194,137
# 2                         3.14%                       287,614
# 3                         0.89%                       105,744
# 4                            2%                       162,647
# 5                         0.68%                        32,379
# 6                        -0.37%                        81,697
# 7                         1.39%                        16,636
# 8                        -1.46%                        30,245
# 9                        -4.13%                        12,258
#
#   change in percent - 2010-2040
# 0                         9.49%
# 1                        14.02%
# 2                        11.27%
# 3                         6.67%
# 4                         7.23%
# 5                         6.91%
# 6                         6.48%
# 7                         6.28%
# 8                         7.12%
# 9                         7.77%

# %%
nyc_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age group                             18 non-null     object
#  1   borough                               18 non-null     object
#  2   2010                                  18 non-null     object
#  3   % of total borough population - 2010  18 non-null     object
#  4   2020                                  18 non-null     object
#  5   % of total borough population - 2020  18 non-null     object
#  6   2030                                  18 non-null     object
#  7   % of total borough population - 2030  18 non-null     object
#  8   2040                                  18 non-null     object
#  9   % of total borough population - 2040  18 non-null     object
#  10  change in number - 2010-2020          18 non-null     object
#  11  change in percent - 2010-2020         18 non-null     object
#  12  change in number - 2020-2030          18 non-null     object
#  13  change in percent - 2020-2030         18 non-null     object
#  14  change in number - 2030-2040          18 non-null     object
#  15  change in percent - 2030-2040         18 non-null     object
#  16  change in number - 2010-2040          18 non-null     object
#  17  change in percent - 2010-2040         18 non-null     object
# dtypes: object(18)
# memory usage: 2.7+ KB

# %%
#changing the values of borough in the nyc_pop to lower case so that the data can merge with nyc_sights
nyc_pop['borough'] = nyc_pop['borough'].str.lower()

# %%
nyc_pop.head(5)
# Out:
#   age group        borough       2010 % of total borough population - 2010  \
# 0     Total  new york city  8,242,624                              100.00%
# 1     Total          bronx  1,385,108                              100.00%
# 2     Total       brooklyn  2,552,911                              100.00%
# 3     Total      manhattan  1,585,873                              100.00%
# 4     Total         queens  2,250,002                              100.00%
#
#         2020 % of total borough population - 2020       2030  \
# 0  8,550,971                              100.00%  8,821,027
# 1  1,446,788                              100.00%  1,518,998
# 2  2,648,452                              100.00%  2,754,009
# 3  1,638,281                              100.00%  1,676,720
# 4  2,330,295                              100.00%  2,373,551
#
#   % of total borough population - 2030       2040  \
# 0                              100.00%  9,025,145
# 1                              100.00%  1,579,245
# 2                              100.00%  2,840,525
# 3                              100.00%  1,691,617
# 4                              100.00%  2,412,649
#
#   % of total borough population - 2040 change in number - 2010-2020  \
# 0                              100.00%                      308,347
# 1                              100.00%                       61,680
# 2                              100.00%                       95,541
# 3                              100.00%                       52,408
# 4                              100.00%                       80,293
#
#   change in percent - 2010-2020 change in number - 2020-2030   \
# 0                         3.74%                       270,056
# 1                         4.45%                        72,210
# 2                         3.74%                       105,557
# 3                         3.30%                        38,439
# 4                         3.57%                        43,256
#
#   change in percent - 2020-2030 change in number - 2030-2040   \
# 0                         3.16%                       204,118
# 1                         4.99%                        60,247
# 2                         3.99%                        86,516
# 3                            2%                        14,897
# 4                         1.86%                        39,098
#
#   change in percent - 2030-2040 change in number - 2010-2040   \
# 0                         2.31%                       782,521
# 1                         3.97%                       194,137
# 2                         3.14%                       287,614
# 3                         0.89%                       105,744
# 4                            2%                       162,647
#
#   change in percent - 2010-2040
# 0                         9.49%
# 1                        14.02%
# 2                        11.27%
# 3                         6.67%
# 4                         7.23%

# %%
nyc_pop['borough'].value_counts()
# Out:
# new york city       3
#    bronx            3
#    brooklyn         3
#    manhattan        3
#    queens           3
#    staten island    3
# Name: borough, dtype: int64

# %%
#The values for borough in nyc_pop dataframe have spaces before them, remove the spaces to perform merging.
nyc_pop['borough'].replace(to_replace =['   bronx'], value = ['bronx'], inplace = True)
nyc_pop['borough'].replace(to_replace =['   brooklyn'], value = ['brooklyn'], inplace = True)
nyc_pop['borough'].replace(to_replace =['   manhattan'], value = ['manhattan'], inplace = True)
nyc_pop['borough'].replace(to_replace =['   queens'], value = ['queens'], inplace = True)
nyc_pop['borough'].replace(to_replace =['   staten island'], value = ['staten island'], inplace = True)

# %%
nyc_pop['borough'].value_counts()
# Out:
# new york city    3
# bronx            3
# brooklyn         3
# manhattan        3
# queens           3
# staten island    3
# Name: borough, dtype: int64

# %%
#merging population data and sightings data.
nyc_data = pd.merge(nyc_sights, nyc_pop, on = 'borough')
nyc_data.head()
# Out:
#   time of reported rat sighting                 location type  incident zip  \
# 0                    9:38:29 AM         Other (Explain Below)       11432.0
# 1                    9:38:29 AM         Other (Explain Below)       11432.0
# 2                    9:38:29 AM         Other (Explain Below)       11432.0
# 3                    9:04:46 AM  3+ Family Mixed Use Building       11375.0
# 4                    9:04:46 AM  3+ Family Mixed Use Building       11375.0
#
#              incident address          city resolution action updated date  \
# 0                         NaN       JAMAICA                     9:45:41 AM
# 1                         NaN       JAMAICA                     9:45:41 AM
# 2                         NaN       JAMAICA                     9:45:41 AM
# 3  68-12 YELLOWSTON BOULEVARD  FOREST HILLS                     9:14:11 AM
# 4  68-12 YELLOWSTON BOULEVARD  FOREST HILLS                     9:14:11 AM
#
#   borough  x coordinate (state plane)  y coordinate (state plane)   latitude  \
# 0  queens                   1039647.0                    195586.0  40.703342
# 1  queens                   1039647.0                    195586.0  40.703342
# 2  queens                   1039647.0                    195586.0  40.703342
# 3  queens                   1026289.0                    203836.0  40.726060
# 4  queens                   1026289.0                    203836.0  40.726060
#
#    longitude                                  location             age group  \
# 0 -73.800203   (40.70334174980328, -73.80020318978804)                 Total
# 1 -73.800203   (40.70334174980328, -73.80020318978804)  School-Age (5 to17)
# 2 -73.800203   (40.70334174980328, -73.80020318978804)           65 and over
# 3 -73.848329  (40.726059538480236, -73.84832900182792)                 Total
# 4 -73.848329  (40.726059538480236, -73.84832900182792)  School-Age (5 to17)
#
#         2010 % of total borough population - 2010       2020  \
# 0  2,250,002                              100.00%  2,330,295
# 1    331,926                               14.75%    341,062
# 2    288,219                               12.81%    325,300
# 3  2,250,002                              100.00%  2,330,295
# 4    331,926                               14.75%    341,062
#
#   % of total borough population - 2020       2030  \
# 0                              100.00%  2,373,551
# 1                               14.64%    350,544
# 2                               13.96%    370,214
# 3                              100.00%  2,373,551
# 4                               14.64%    350,544
#
#   % of total borough population - 2030       2040  \
# 0                              100.00%  2,412,649
# 1                               14.77%    355,340
# 2                               15.60%    377,060
# 3                              100.00%  2,412,649
# 4                               14.77%    355,340
#
#   % of total borough population - 2040 change in number - 2010-2020  \
# 0                              100.00%                       80,293
# 1                               14.73%                        9,137
# 2                               15.63%                       37,081
# 3                              100.00%                       80,293
# 4                               14.73%                        9,137
#
#   change in percent - 2010-2020 change in number - 2020-2030   \
# 0                         3.57%                        43,256
# 1                         2.75%                         9,482
# 2                        12.87%                        44,914
# 3                         3.57%                        43,256
# 4                         2.75%                         9,482
#
#   change in percent - 2020-2030 change in number - 2030-2040   \
# 0                         1.86%                        39,098
# 1                         2.78%                         4,796
# 2                           14%                         6,846
# 3                         1.86%                        39,098
# 4                         2.78%                         4,796
#
#   change in percent - 2030-2040 change in number - 2010-2040   \
# 0                            2%                       162,647
# 1                         1.37%                        23,414
# 2                         1.85%                        88,841
# 3                            2%                       162,647
# 4                         1.37%                        23,414
#
#   change in percent - 2010-2040
# 0                         7.23%
# 1                         7.05%
# 2                        30.82%
# 3                         7.23%
# 4                         7.05%

# %%
nyc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 650757 entries, 0 to 650756
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   time of reported rat sighting         650757 non-null  object
#  1   location type                         650721 non-null  object
#  2   incident zip                          649500 non-null  float64
#  3   incident address                      617979 non-null  object
#  4   city                                  640512 non-null  object
#  5   resolution action updated date        625938 non-null  object
#  6   borough                               650757 non-null  object
#  7   x coordinate (state plane)            644232 non-null  float64
#  8   y coordinate (state plane)            644238 non-null  float64
#  9   latitude                              644232 non-null  float64
#  10  longitude                             644232 non-null  float64
#  11  location                              644232 non-null  object
#  12  age group                             650757 non-null  object
#  13  2010                                  650757 non-null  object
#  14  % of total borough population - 2010  650757 non-null  object
#  15  2020                                  650757 non-null  object
#  16  % of total borough population - 2020  650757 non-null  object
#  17  2030                                  650757 non-null  object
#  18  % of total borough population - 2030  650757 non-null  object
#  19  2040                                  650757 non-null  object
#  20  % of total borough population - 2040  650757 non-null  object
#  21  change in number - 2010-2020          650757 non-null  object
#  22  change in percent - 2010-2020         650757 non-null  object
#  23  change in number - 2020-2030          650757 non-null  object
#  24  change in percent - 2020-2030         650757 non-null  object
#  25  change in number - 2030-2040          650757 non-null  object
#  26  change in percent - 2030-2040         650757 non-null  object
#  27  change in number - 2010-2040          650757 non-null  object
#  28  change in percent - 2010-2040         650757 non-null  object
# dtypes: float64(5), object(24)
# memory usage: 148.9+ MB

# %%
nyc_data.borough.value_counts()
# Out:
# brooklyn         234957
# manhattan        172488
# bronx            120336
# queens            96663
# staten island     26313
# Name: borough, dtype: int64

# %%
nyc_climate = pd.read_csv('Climate_and_Health_data cleaned.csv')
nyc_climate.columns = map(str.lower, nyc_climate.columns)
nyc_climate.head(10)
# Out:
#                 title                                 indicator_name  \
# 0  Climate and Health  Homes near structures rated good or excellent
# 1  Climate and Health  Homes near structures rated good or excellent
# 2  Climate and Health  Homes near structures rated good or excellent
# 3  Climate and Health  Homes near structures rated good or excellent
# 4  Climate and Health  Homes near structures rated good or excellent
# 5  Climate and Health  Homes near structures rated good or excellent
# 6  Climate and Health  Homes near structures rated good or excellent
# 7  Climate and Health  Homes near structures rated good or excellent
# 8  Climate and Health  Homes near structures rated good or excellent
# 9  Climate and Health  Homes near structures rated good or excellent
#
#                          neighborhood  % reported good or excellent
# 0             Kingsbridge - Riverdale                          73.6
# 1                     Northeast Bronx                          78.6
# 2                  Fordham - Bronx Pk                          57.7
# 3                Pelham - Throgs Neck                          71.4
# 4                    Crotona -Tremont                          39.1
# 5            High Bridge - Morrisania                          36.9
# 6            Hunts Point - Mott Haven                          44.2
# 7                          Greenpoint                          86.7
# 8          Downtown - Heights - Slope                          79.6
# 9  Bedford Stuyvesant - Crown Heights                          59.1

# %%
nyc_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3444 entries, 0 to 3443
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         3444 non-null   object
#  1   indicator_name                3444 non-null   object
#  2   neighborhood                  3444 non-null   object
#  3   % reported good or excellent  3418 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 107.8+ KB

# %%
nyc_Asthma = pd.read_csv('Asthma_and_the_Environment_data CLEANED.csv')
nyc_Asthma.columns = map(str.lower, nyc_Asthma.columns)
nyc_Asthma.head(10)
# Out:
#    asthma and the environment                        neighborhood  % reported
# 0  Asthma and the Environment             Kingsbridge - Riverdale         5.1
# 1  Asthma and the Environment                     Northeast Bronx         5.9
# 2  Asthma and the Environment                  Fordham - Bronx Pk         4.8
# 3  Asthma and the Environment                Pelham - Throgs Neck         6.1
# 4  Asthma and the Environment                    Crotona -Tremont         8.8
# 5  Asthma and the Environment            High Bridge - Morrisania         8.8
# 6  Asthma and the Environment            Hunts Point - Mott Haven         8.8
# 7  Asthma and the Environment                          Greenpoint         3.1
# 8  Asthma and the Environment          Downtown - Heights - Slope         6.5
# 9  Asthma and the Environment  Bedford Stuyvesant - Crown Heights         5.9

# %%
nyc_Asthma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7182 entries, 0 to 7181
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   asthma and the environment  7182 non-null   object
#  1   neighborhood                7182 non-null   object
#  2   % reported                  7095 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 168.5+ KB

# %%
climate_asthma = pd.merge(nyc_Asthma, nyc_climate, on = 'neighborhood')
climate_asthma.head()
# Out:
#    asthma and the environment             neighborhood  % reported  \
# 0  Asthma and the Environment  Kingsbridge - Riverdale         5.1
# 1  Asthma and the Environment  Kingsbridge - Riverdale         5.1
# 2  Asthma and the Environment  Kingsbridge - Riverdale         5.1
# 3  Asthma and the Environment  Kingsbridge - Riverdale         5.1
# 4  Asthma and the Environment  Kingsbridge - Riverdale         5.1
#
#                 title                                 indicator_name  \
# 0  Climate and Health  Homes near structures rated good or excellent
# 1  Climate and Health  Homes near structures rated good or excellent
# 2  Climate and Health  Homes near structures rated good or excellent
# 3  Climate and Health  Homes near structures rated good or excellent
# 4  Climate and Health                                     Ozone (O3)
#
#    % reported good or excellent
# 0                         73.60
# 1                         80.60
# 2                         78.80
# 3                         79.20
# 4                         23.67

# %%
climate_asthma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588924 entries, 0 to 588923
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   asthma and the environment    588924 non-null  object
#  1   neighborhood                  588924 non-null  object
#  2   % reported                    581790 non-null  float64
#  3   title                         588924 non-null  object
#  4   indicator_name                588924 non-null  object
#  5   % reported good or excellent  584478 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 31.5+ MB

# %%
climate_asthma.rename(columns = {'title':'climate and the environment','% reported' : '% reported good or exellent_Asthma','% reported good or excellent':'% reported good or excellent_climate' }, inplace = True)

# %%
climate_asthma.head()
# Out:
#    asthma and the environment             neighborhood  \
# 0  Asthma and the Environment  Kingsbridge - Riverdale
# 1  Asthma and the Environment  Kingsbridge - Riverdale
# 2  Asthma and the Environment  Kingsbridge - Riverdale
# 3  Asthma and the Environment  Kingsbridge - Riverdale
# 4  Asthma and the Environment  Kingsbridge - Riverdale
#
#    % reported good or exellent_Asthma climate and the environment  \
# 0                                 5.1          Climate and Health
# 1                                 5.1          Climate and Health
# 2                                 5.1          Climate and Health
# 3                                 5.1          Climate and Health
# 4                                 5.1          Climate and Health
#
#                                   indicator_name  \
# 0  Homes near structures rated good or excellent
# 1  Homes near structures rated good or excellent
# 2  Homes near structures rated good or excellent
# 3  Homes near structures rated good or excellent
# 4                                     Ozone (O3)
#
#    % reported good or excellent_climate
# 0                                 73.60
# 1                                 80.60
# 2                                 78.80
# 3                                 79.20
# 4                                 23.67

# %%
def classify_borough(neighborhood):
    if neighborhood in ['Kingsbridge - Riverdale','Northeast Bronx','Fordham - Bronx Park',
                        'Pelham - Throgs Neck','Crotona - Tremont','High Bridge - Morrisania','Hunts Point - Mott Have']:
        return 'bronx'
    if neighborhood in ['Greenpoint','Williamsburg - Bushwick','Downtown - Heights - Park Slope','Bedford Stuyvesant - Crown Heights',
                        'East New York','Sunset Park','Borough Park','East Flatbush - latbush','Canarsie - Flatlands','Bensonhurst - Bay Ridge','Coney Island - Sheepshead Bay']:
        return 'brooklyn'
    if neighborhood in ['Washington Heights - Inwood','Central Harlem - Morningside Heights','East Harlem','Upper West Side','Upper East Side',
                       'Chelsea - Clinton','Gramercy Park - Murray Hill','Greenwich Village - SoHo','Union Square - Lower East Side','Lower Manhattan']:
        return 'manhattan'
    if neighborhood in ['Long Island City - Astoria','West Queens','Flushing - Clearview','Bayside - Little Neck','Ridgewood - Forest Hills',
                       'Fresh Meadows','Southwest Queens','Jamaica','Southeast Queens','Rockaway']:
        return 'queens'
    if neighborhood in ['Port Richmond','Stapleton - St. George','Willowbrook','South Beach - Tottenville']:
        return 'staten island'
    
    else:
        return 'other'
#apply the function to classify the neighborhoods into boroughs.
climate_asthma['borough'] = climate_asthma['neighborhood'].apply(classify_borough)

# %%
climate_asthma.head()
# Out:
#    asthma and the environment             neighborhood  \
# 0  Asthma and the Environment  Kingsbridge - Riverdale
# 1  Asthma and the Environment  Kingsbridge - Riverdale
# 2  Asthma and the Environment  Kingsbridge - Riverdale
# 3  Asthma and the Environment  Kingsbridge - Riverdale
# 4  Asthma and the Environment  Kingsbridge - Riverdale
#
#    % reported good or exellent_Asthma climate and the environment  \
# 0                                 5.1          Climate and Health
# 1                                 5.1          Climate and Health
# 2                                 5.1          Climate and Health
# 3                                 5.1          Climate and Health
# 4                                 5.1          Climate and Health
#
#                                   indicator_name  \
# 0  Homes near structures rated good or excellent
# 1  Homes near structures rated good or excellent
# 2  Homes near structures rated good or excellent
# 3  Homes near structures rated good or excellent
# 4                                     Ozone (O3)
#
#    % reported good or excellent_climate borough
# 0                                 73.60   bronx
# 1                                 80.60   bronx
# 2                                 78.80   bronx
# 3                                 79.20   bronx
# 4                                 23.67   bronx

# %%
climate_asthma.borough.value_counts()
# Out:
# brooklyn         126198
# manhattan        126198
# queens           126198
# other             98154
# bronx             56088
# staten island     56088
# Name: borough, dtype: int64

# %%
borough =
